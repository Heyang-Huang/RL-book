# %%
from dataclasses import dataclass
from typing import Tuple, Dict, Generator,Callable,Optional
import numpy as np
import matplotlib.pyplot as plt
import itertools
import os
os.chdir("..")
from rl.markov_process import MarkovRewardProcess,FiniteMarkovProcess,MarkovProcess
from rl.markov_process import FiniteMarkovRewardProcess
from rl.markov_process import Transition
from rl.markov_process import RewardTransition
from rl.distribution import Constant,Categorical,SampledDistribution

# %% [markdown]
# ## List of questions:
# <a href='#Q1'>Q1</a> After I get a trace from Class FMP, I use plt.hist and my own trace_distribution() to get distribution. My solution doesn't look efficient enough to me. Why isn't there a method in FiniteMarkovProcess() class to perform the sampling and ploting task? Any suggestions for my implementation?
# <br><a href='#Q2'>Q2</a> That's my first time to write OOP with python. Are there any design and syntax suggestions to make my code more "modular" as stated in grading criteria in syllabus?
# <br><a href='#Q3'>Q3</a> I create the interface StockPriceMP1(MarkovRewardProcess[StateMP1]) and definition of transition_reward() method is required due to inheritence. Do I still need to specify method transition_reward() as @abstractmethod, since it's already stated in MarkovRewardProcess interface?
# <br>4.
# <br>5.

# %% [markdown]
# <h1><center>Snakes and Ladders(p1,p2,p4)</center></h1>

# %% [markdown]
# <br><a id='Q2'></a>

# %%
@dataclass(frozen=True)
class SALState:
    '''Snake and Ladder Game State Object
    '''
    step: int
        
class SAL():
    '''Snake and Ladder Object: np.array of shape(x,2) where for each x x[0]
    is the starting point and x[1] is the end point. x is the current number of 
    all snakes/ladders that have been added by method add()
    '''
    SALArray: np.ndarray
    def __init__(
        self
    ):
        self.SALArray:np.ndarray = np.empty(shape=(0, 2))
            
    def add(
        self,
        newSAL: list
    ):
        '''add another snake/ladder
        '''
        self.SALArray=np.append(self.SALArray,np.array(newSAL).reshape((-1, 2)), axis=0)
    def getSAL(self) -> np.ndarray:
        '''return all snake/ladders that have been added
        '''
        return self.SALArray
    
    
class SALMPFinite(FiniteMarkovProcess[SALState]):
    '''Model the game in FMP
    '''
    def __init__(
        self,
        snakePos: np.ndarray,
        ladderPos: np.ndarray
    ):
        self.snakePos: np.ndarray = snakePos
        self.ladderPos: np.ndarray = ladderPos
        super().__init__(self.get_transition_map())

    def get_transition_map(self) -> Transition[SALState]:
        '''
        Transition map of FMP
        '''
        d: Dict[InventoryState, Categorical[InventoryState]] = {}
        for currentStep in range(100):
            state_probs_map: Mapping[SALState, float] = {}
            for dice in range(1,7):
                finalStep,probMultiplier = self.get_final_state(currentStep+dice)
                state_probs_map[SALState(int(finalStep))]=probMultiplier*1/6
                #probMutiplier is used to capture the corner cases near destination
                d[SALState(currentStep)] = Categorical(state_probs_map)
        d[SALState(100)]=None
        return d
    
    def get_final_state(self,nxtStep: int) -> Tuple[int,int]:
        """Use Recursion to get final location wrt nxtStep"""
        # arrive or go beyond destination
        if nxtStep>99:
            probMultiplier=nxtStep-99
            step=100
        else:
            probMultiplier=1
            step=nxtStep
        # snake and ladder cases
        for snake in self.snakePos:
            if snake[0]==nxtStep:
                step,probMultiplier=self.get_final_state(snake[1])
                break
                
        for ladder in self.ladderPos:
            if ladder[0]==nxtStep:
                step,probMultiplier=self.get_final_state(ladder[1])
                break
        return step,probMultiplier

# %%
snake=SAL()
ladder=SAL()

snake.add([16,6])
snake.add([47,26])
snake.add([49,11])
snake.add([56,53])
snake.add([62,19])
snake.add([64,60])
snake.add([87,24])
snake.add([93,73])
snake.add([95,75])
snake.add([98,78])

ladder.add([1,38])
ladder.add([4,14])
ladder.add([9,31])
ladder.add([21,42])
ladder.add([28,84])
ladder.add([36,44])
ladder.add([51,67])
ladder.add([71,91])
ladder.add([80,100])

newGame = SALMPFinite(
        snakePos=snake.getSAL(),
        ladderPos=ladder.getSAL()       
)


print("Transition Map")
print("--------------")
print(FiniteMarkovProcess(newGame.transition_map))
# Out:
# Transition Map
# --------------
# From State SALState(step=0):
#   To State SALState(step=38) with Probability 0.167
#   To State SALState(step=2) with Probability 0.167
#   To State SALState(step=3) with Probability 0.167
#   To State SALState(step=14) with Probability 0.167
#   To State SALState(step=5) with Probability 0.167
#   To State SALState(step=6) with Probability 0.167
# From State SALState(step=1):
#   To State SALState(step=2) with Probability 0.167
#   To State SALState(step=3) with Probability 0.167
#   To State SALState(step=14) with Probability 0.167
#   To State SALState(step=5) with Probability 0.167
#   To State SALState(step=6) with Probability 0.167
#   To State SALState(step=7) with Probability 0.167
# From State SALState(step=2):
#   To State SALState(step=3) with Probability 0.167
#   To State SALState(step=14) with Probability 0.167
#   To State SALState(step=5) with Probability 0.167
#   To State SALState(step=6) with Probability 0.167
#   To State SALState(step=7) with Probability 0.167
#   To State SALState(step=8) with Probability 0.167
# From State SALState(step=3):
#   To State SALState(step=14) with Probability 0.167
#   To State SALState(step=5) with Probability 0.167
#   To State SALState(step=6) with Probability 0.167
#   To State SALState(step=7) with Probability 0.167
#   To State SALState(step=8) with Probability 0.167
#   To State SALState(step=31) with Probability 0.167
# From State SALState(step=4):
#   To State SALState(step=5) with Probability 0.167
#   To State SALState(step=6) with Probability 0.167
#   To State SALState(step=7) with Probability 0.167
#   To State SALState(step=8) with Probability 0.167
#   To State SALState(step=31) with Probability 0.167
#   To State SALState(step=10) with Probability 0.167
# From State SALState(step=5):
#   To State SALState(step=6) with Probability 0.167
#   To State SALState(step=7) with Probability 0.167
#   To State SALState(step=8) with Probability 0.167
#   To State SALState(step=31) with Probability 0.167
#   To State SALState(step=10) with Probability 0.167
#   To State SALState(step=11) with Probability 0.167
# From State SALState(step=6):
#   To State SALState(step=7) with Probability 0.167
#   To State SALState(step=8) with Probability 0.167
#   To State SALState(step=31) with Probability 0.167
#   To State SALState(step=10) with Probability 0.167
#   To State SALState(step=11) with Probability 0.167
#   To State SALState(step=12) with Probability 0.167
# From State SALState(step=7):
#   To State SALState(step=8) with Probability 0.167
#   To State SALState(step=31) with Probability 0.167
#   To State SALState(step=10) with Probability 0.167
#   To State SALState(step=11) with Probability 0.167
#   To State SALState(step=12) with Probability 0.167
#   To State SALState(step=13) with Probability 0.167
# From State SALState(step=8):
#   To State SALState(step=31) with Probability 0.167
#   To State SALState(step=10) with Probability 0.167
#   To State SALState(step=11) with Probability 0.167
#   To State SALState(step=12) with Probability 0.167
#   To State SALState(step=13) with Probability 0.167
#   To State SALState(step=14) with Probability 0.167
# From State SALState(step=9):
#   To State SALState(step=10) with Probability 0.167
#   To State SALState(step=11) with Probability 0.167
#   To State SALState(step=12) with Probability 0.167
#   To State SALState(step=13) with Probability 0.167
#   To State SALState(step=14) with Probability 0.167
#   To State SALState(step=15) with Probability 0.167
# From State SALState(step=10):
#   To State SALState(step=11) with Probability 0.167
#   To State SALState(step=12) with Probability 0.167
#   To State SALState(step=13) with Probability 0.167
#   To State SALState(step=14) with Probability 0.167
#   To State SALState(step=15) with Probability 0.167
#   To State SALState(step=6) with Probability 0.167
# From State SALState(step=11):
#   To State SALState(step=12) with Probability 0.167
#   To State SALState(step=13) with Probability 0.167
#   To State SALState(step=14) with Probability 0.167
#   To State SALState(step=15) with Probability 0.167
#   To State SALState(step=6) with Probability 0.167
#   To State SALState(step=17) with Probability 0.167
# From State SALState(step=12):
#   To State SALState(step=13) with Probability 0.167
#   To State SALState(step=14) with Probability 0.167
#   To State SALState(step=15) with Probability 0.167
#   To State SALState(step=6) with Probability 0.167
#   To State SALState(step=17) with Probability 0.167
#   To State SALState(step=18) with Probability 0.167
# From State SALState(step=13):
#   To State SALState(step=14) with Probability 0.167
#   To State SALState(step=15) with Probability 0.167
#   To State SALState(step=6) with Probability 0.167
#   To State SALState(step=17) with Probability 0.167
#   To State SALState(step=18) with Probability 0.167
#   To State SALState(step=19) with Probability 0.167
# From State SALState(step=14):
#   To State SALState(step=15) with Probability 0.167
#   To State SALState(step=6) with Probability 0.167
#   To State SALState(step=17) with Probability 0.167
#   To State SALState(step=18) with Probability 0.167
#   To State SALState(step=19) with Probability 0.167
#   To State SALState(step=20) with Probability 0.167
# From State SALState(step=15):
#   To State SALState(step=6) with Probability 0.167
#   To State SALState(step=17) with Probability 0.167
#   To State SALState(step=18) with Probability 0.167
#   To State SALState(step=19) with Probability 0.167
#   To State SALState(step=20) with Probability 0.167
#   To State SALState(step=42) with Probability 0.167
# From State SALState(step=16):
#   To State SALState(step=17) with Probability 0.167
#   To State SALState(step=18) with Probability 0.167
#   To State SALState(step=19) with Probability 0.167
#   To State SALState(step=20) with Probability 0.167
#   To State SALState(step=42) with Probability 0.167
#   To State SALState(step=22) with Probability 0.167
# From State SALState(step=17):
#   To State SALState(step=18) with Probability 0.167
#   To State SALState(step=19) with Probability 0.167
#   To State SALState(step=20) with Probability 0.167
#   To State SALState(step=42) with Probability 0.167
#   To State SALState(step=22) with Probability 0.167
#   To State SALState(step=23) with Probability 0.167
# From State SALState(step=18):
#   To State SALState(step=19) with Probability 0.167
#   To State SALState(step=20) with Probability 0.167
#   To State SALState(step=42) with Probability 0.167
#   To State SALState(step=22) with Probability 0.167
#   To State SALState(step=23) with Probability 0.167
#   To State SALState(step=24) with Probability 0.167
# From State SALState(step=19):
#   To State SALState(step=20) with Probability 0.167
#   To State SALState(step=42) with Probability 0.167
#   To State SALState(step=22) with Probability 0.167
#   To State SALState(step=23) with Probability 0.167
#   To State SALState(step=24) with Probability 0.167
#   To State SALState(step=25) with Probability 0.167
# From State SALState(step=20):
#   To State SALState(step=42) with Probability 0.167
#   To State SALState(step=22) with Probability 0.167
#   To State SALState(step=23) with Probability 0.167
#   To State SALState(step=24) with Probability 0.167
#   To State SALState(step=25) with Probability 0.167
#   To State SALState(step=26) with Probability 0.167
# From State SALState(step=21):
#   To State SALState(step=22) with Probability 0.167
#   To State SALState(step=23) with Probability 0.167
#   To State SALState(step=24) with Probability 0.167
#   To State SALState(step=25) with Probability 0.167
#   To State SALState(step=26) with Probability 0.167
#   To State SALState(step=27) with Probability 0.167
# From State SALState(step=22):
#   To State SALState(step=23) with Probability 0.167
#   To State SALState(step=24) with Probability 0.167
#   To State SALState(step=25) with Probability 0.167
#   To State SALState(step=26) with Probability 0.167
#   To State SALState(step=27) with Probability 0.167
#   To State SALState(step=84) with Probability 0.167
# From State SALState(step=23):
#   To State SALState(step=24) with Probability 0.167
#   To State SALState(step=25) with Probability 0.167
#   To State SALState(step=26) with Probability 0.167
#   To State SALState(step=27) with Probability 0.167
#   To State SALState(step=84) with Probability 0.167
#   To State SALState(step=29) with Probability 0.167
# From State SALState(step=24):
#   To State SALState(step=25) with Probability 0.167
#   To State SALState(step=26) with Probability 0.167
#   To State SALState(step=27) with Probability 0.167
#   To State SALState(step=84) with Probability 0.167
#   To State SALState(step=29) with Probability 0.167
#   To State SALState(step=30) with Probability 0.167
# From State SALState(step=25):
#   To State SALState(step=26) with Probability 0.167
#   To State SALState(step=27) with Probability 0.167
#   To State SALState(step=84) with Probability 0.167
#   To State SALState(step=29) with Probability 0.167
#   To State SALState(step=30) with Probability 0.167
#   To State SALState(step=31) with Probability 0.167
# From State SALState(step=26):
#   To State SALState(step=27) with Probability 0.167
#   To State SALState(step=84) with Probability 0.167
#   To State SALState(step=29) with Probability 0.167
#   To State SALState(step=30) with Probability 0.167
#   To State SALState(step=31) with Probability 0.167
#   To State SALState(step=32) with Probability 0.167
# From State SALState(step=27):
#   To State SALState(step=84) with Probability 0.167
#   To State SALState(step=29) with Probability 0.167
#   To State SALState(step=30) with Probability 0.167
#   To State SALState(step=31) with Probability 0.167
#   To State SALState(step=32) with Probability 0.167
#   To State SALState(step=33) with Probability 0.167
# From State SALState(step=28):
#   To State SALState(step=29) with Probability 0.167
#   To State SALState(step=30) with Probability 0.167
#   To State SALState(step=31) with Probability 0.167
#   To State SALState(step=32) with Probability 0.167
#   To State SALState(step=33) with Probability 0.167
#   To State SALState(step=34) with Probability 0.167
# From State SALState(step=29):
#   To State SALState(step=30) with Probability 0.167
#   To State SALState(step=31) with Probability 0.167
#   To State SALState(step=32) with Probability 0.167
#   To State SALState(step=33) with Probability 0.167
#   To State SALState(step=34) with Probability 0.167
#   To State SALState(step=35) with Probability 0.167
# From State SALState(step=30):
#   To State SALState(step=31) with Probability 0.167
#   To State SALState(step=32) with Probability 0.167
#   To State SALState(step=33) with Probability 0.167
#   To State SALState(step=34) with Probability 0.167
#   To State SALState(step=35) with Probability 0.167
#   To State SALState(step=44) with Probability 0.167
# From State SALState(step=31):
#   To State SALState(step=32) with Probability 0.167
#   To State SALState(step=33) with Probability 0.167
#   To State SALState(step=34) with Probability 0.167
#   To State SALState(step=35) with Probability 0.167
#   To State SALState(step=44) with Probability 0.167
#   To State SALState(step=37) with Probability 0.167
# From State SALState(step=32):
#   To State SALState(step=33) with Probability 0.167
#   To State SALState(step=34) with Probability 0.167
#   To State SALState(step=35) with Probability 0.167
#   To State SALState(step=44) with Probability 0.167
#   To State SALState(step=37) with Probability 0.167
#   To State SALState(step=38) with Probability 0.167
# From State SALState(step=33):
#   To State SALState(step=34) with Probability 0.167
#   To State SALState(step=35) with Probability 0.167
#   To State SALState(step=44) with Probability 0.167
#   To State SALState(step=37) with Probability 0.167
#   To State SALState(step=38) with Probability 0.167
#   To State SALState(step=39) with Probability 0.167
# From State SALState(step=34):
#   To State SALState(step=35) with Probability 0.167
#   To State SALState(step=44) with Probability 0.167
#   To State SALState(step=37) with Probability 0.167
#   To State SALState(step=38) with Probability 0.167
#   To State SALState(step=39) with Probability 0.167
#   To State SALState(step=40) with Probability 0.167
# From State SALState(step=35):
#   To State SALState(step=44) with Probability 0.167
#   To State SALState(step=37) with Probability 0.167
#   To State SALState(step=38) with Probability 0.167
#   To State SALState(step=39) with Probability 0.167
#   To State SALState(step=40) with Probability 0.167
#   To State SALState(step=41) with Probability 0.167
# From State SALState(step=36):
#   To State SALState(step=37) with Probability 0.167
#   To State SALState(step=38) with Probability 0.167
#   To State SALState(step=39) with Probability 0.167
#   To State SALState(step=40) with Probability 0.167
#   To State SALState(step=41) with Probability 0.167
#   To State SALState(step=42) with Probability 0.167
# From State SALState(step=37):
#   To State SALState(step=38) with Probability 0.167
#   To State SALState(step=39) with Probability 0.167
#   To State SALState(step=40) with Probability 0.167
#   To State SALState(step=41) with Probability 0.167
#   To State SALState(step=42) with Probability 0.167
#   To State SALState(step=43) with Probability 0.167
# From State SALState(step=38):
#   To State SALState(step=39) with Probability 0.167
#   To State SALState(step=40) with Probability 0.167
#   To State SALState(step=41) with Probability 0.167
#   To State SALState(step=42) with Probability 0.167
#   To State SALState(step=43) with Probability 0.167
#   To State SALState(step=44) with Probability 0.167
# From State SALState(step=39):
#   To State SALState(step=40) with Probability 0.167
#   To State SALState(step=41) with Probability 0.167
#   To State SALState(step=42) with Probability 0.167
#   To State SALState(step=43) with Probability 0.167
#   To State SALState(step=44) with Probability 0.167
#   To State SALState(step=45) with Probability 0.167
# From State SALState(step=40):
#   To State SALState(step=41) with Probability 0.167
#   To State SALState(step=42) with Probability 0.167
#   To State SALState(step=43) with Probability 0.167
#   To State SALState(step=44) with Probability 0.167
#   To State SALState(step=45) with Probability 0.167
#   To State SALState(step=46) with Probability 0.167
# From State SALState(step=41):
#   To State SALState(step=42) with Probability 0.167
#   To State SALState(step=43) with Probability 0.167
#   To State SALState(step=44) with Probability 0.167
#   To State SALState(step=45) with Probability 0.167
#   To State SALState(step=46) with Probability 0.167
#   To State SALState(step=26) with Probability 0.167
# From State SALState(step=42):
#   To State SALState(step=43) with Probability 0.167
#   To State SALState(step=44) with Probability 0.167
#   To State SALState(step=45) with Probability 0.167
#   To State SALState(step=46) with Probability 0.167
#   To State SALState(step=26) with Probability 0.167
#   To State SALState(step=48) with Probability 0.167
# From State SALState(step=43):
#   To State SALState(step=44) with Probability 0.167
#   To State SALState(step=45) with Probability 0.167
#   To State SALState(step=46) with Probability 0.167
#   To State SALState(step=26) with Probability 0.167
#   To State SALState(step=48) with Probability 0.167
#   To State SALState(step=11) with Probability 0.167
# From State SALState(step=44):
#   To State SALState(step=45) with Probability 0.167
#   To State SALState(step=46) with Probability 0.167
#   To State SALState(step=26) with Probability 0.167
#   To State SALState(step=48) with Probability 0.167
#   To State SALState(step=11) with Probability 0.167
#   To State SALState(step=50) with Probability 0.167
# From State SALState(step=45):
#   To State SALState(step=46) with Probability 0.167
#   To State SALState(step=26) with Probability 0.167
#   To State SALState(step=48) with Probability 0.167
#   To State SALState(step=11) with Probability 0.167
#   To State SALState(step=50) with Probability 0.167
#   To State SALState(step=67) with Probability 0.167
# From State SALState(step=46):
#   To State SALState(step=26) with Probability 0.167
#   To State SALState(step=48) with Probability 0.167
#   To State SALState(step=11) with Probability 0.167
#   To State SALState(step=50) with Probability 0.167
#   To State SALState(step=67) with Probability 0.167
#   To State SALState(step=52) with Probability 0.167
# From State SALState(step=47):
#   To State SALState(step=48) with Probability 0.167
#   To State SALState(step=11) with Probability 0.167
#   To State SALState(step=50) with Probability 0.167
#   To State SALState(step=67) with Probability 0.167
#   To State SALState(step=52) with Probability 0.167
#   To State SALState(step=53) with Probability 0.167
# From State SALState(step=48):
#   To State SALState(step=11) with Probability 0.167
#   To State SALState(step=50) with Probability 0.167
#   To State SALState(step=67) with Probability 0.167
#   To State SALState(step=52) with Probability 0.167
#   To State SALState(step=53) with Probability 0.167
#   To State SALState(step=54) with Probability 0.167
# From State SALState(step=49):
#   To State SALState(step=50) with Probability 0.167
#   To State SALState(step=67) with Probability 0.167
#   To State SALState(step=52) with Probability 0.167
#   To State SALState(step=53) with Probability 0.167
#   To State SALState(step=54) with Probability 0.167
#   To State SALState(step=55) with Probability 0.167
# From State SALState(step=50):
#   To State SALState(step=67) with Probability 0.200
#   To State SALState(step=52) with Probability 0.200
#   To State SALState(step=53) with Probability 0.200
#   To State SALState(step=54) with Probability 0.200
#   To State SALState(step=55) with Probability 0.200
# From State SALState(step=51):
#   To State SALState(step=52) with Probability 0.200
#   To State SALState(step=53) with Probability 0.200
#   To State SALState(step=54) with Probability 0.200
#   To State SALState(step=55) with Probability 0.200
#   To State SALState(step=57) with Probability 0.200
# From State SALState(step=52):
#   To State SALState(step=53) with Probability 0.200
#   To State SALState(step=54) with Probability 0.200
#   To State SALState(step=55) with Probability 0.200
#   To State SALState(step=57) with Probability 0.200
#   To State SALState(step=58) with Probability 0.200
# From State SALState(step=53):
#   To State SALState(step=54) with Probability 0.167
#   To State SALState(step=55) with Probability 0.167
#   To State SALState(step=53) with Probability 0.167
#   To State SALState(step=57) with Probability 0.167
#   To State SALState(step=58) with Probability 0.167
#   To State SALState(step=59) with Probability 0.167
# From State SALState(step=54):
#   To State SALState(step=55) with Probability 0.167
#   To State SALState(step=53) with Probability 0.167
#   To State SALState(step=57) with Probability 0.167
#   To State SALState(step=58) with Probability 0.167
#   To State SALState(step=59) with Probability 0.167
#   To State SALState(step=60) with Probability 0.167
# From State SALState(step=55):
#   To State SALState(step=53) with Probability 0.167
#   To State SALState(step=57) with Probability 0.167
#   To State SALState(step=58) with Probability 0.167
#   To State SALState(step=59) with Probability 0.167
#   To State SALState(step=60) with Probability 0.167
#   To State SALState(step=61) with Probability 0.167
# From State SALState(step=56):
#   To State SALState(step=57) with Probability 0.167
#   To State SALState(step=58) with Probability 0.167
#   To State SALState(step=59) with Probability 0.167
#   To State SALState(step=60) with Probability 0.167
#   To State SALState(step=61) with Probability 0.167
#   To State SALState(step=19) with Probability 0.167
# From State SALState(step=57):
#   To State SALState(step=58) with Probability 0.167
#   To State SALState(step=59) with Probability 0.167
#   To State SALState(step=60) with Probability 0.167
#   To State SALState(step=61) with Probability 0.167
#   To State SALState(step=19) with Probability 0.167
#   To State SALState(step=63) with Probability 0.167
# From State SALState(step=58):
#   To State SALState(step=59) with Probability 0.200
#   To State SALState(step=60) with Probability 0.200
#   To State SALState(step=61) with Probability 0.200
#   To State SALState(step=19) with Probability 0.200
#   To State SALState(step=63) with Probability 0.200
# From State SALState(step=59):
#   To State SALState(step=60) with Probability 0.200
#   To State SALState(step=61) with Probability 0.200
#   To State SALState(step=19) with Probability 0.200
#   To State SALState(step=63) with Probability 0.200
#   To State SALState(step=65) with Probability 0.200
# From State SALState(step=60):
#   To State SALState(step=61) with Probability 0.167
#   To State SALState(step=19) with Probability 0.167
#   To State SALState(step=63) with Probability 0.167
#   To State SALState(step=60) with Probability 0.167
#   To State SALState(step=65) with Probability 0.167
#   To State SALState(step=66) with Probability 0.167
# From State SALState(step=61):
#   To State SALState(step=19) with Probability 0.167
#   To State SALState(step=63) with Probability 0.167
#   To State SALState(step=60) with Probability 0.167
#   To State SALState(step=65) with Probability 0.167
#   To State SALState(step=66) with Probability 0.167
#   To State SALState(step=67) with Probability 0.167
# From State SALState(step=62):
#   To State SALState(step=63) with Probability 0.167
#   To State SALState(step=60) with Probability 0.167
#   To State SALState(step=65) with Probability 0.167
#   To State SALState(step=66) with Probability 0.167
#   To State SALState(step=67) with Probability 0.167
#   To State SALState(step=68) with Probability 0.167
# From State SALState(step=63):
#   To State SALState(step=60) with Probability 0.167
#   To State SALState(step=65) with Probability 0.167
#   To State SALState(step=66) with Probability 0.167
#   To State SALState(step=67) with Probability 0.167
#   To State SALState(step=68) with Probability 0.167
#   To State SALState(step=69) with Probability 0.167
# From State SALState(step=64):
#   To State SALState(step=65) with Probability 0.167
#   To State SALState(step=66) with Probability 0.167
#   To State SALState(step=67) with Probability 0.167
#   To State SALState(step=68) with Probability 0.167
#   To State SALState(step=69) with Probability 0.167
#   To State SALState(step=70) with Probability 0.167
# From State SALState(step=65):
#   To State SALState(step=66) with Probability 0.167
#   To State SALState(step=67) with Probability 0.167
#   To State SALState(step=68) with Probability 0.167
#   To State SALState(step=69) with Probability 0.167
#   To State SALState(step=70) with Probability 0.167
#   To State SALState(step=91) with Probability 0.167
# From State SALState(step=66):
#   To State SALState(step=67) with Probability 0.167
#   To State SALState(step=68) with Probability 0.167
#   To State SALState(step=69) with Probability 0.167
#   To State SALState(step=70) with Probability 0.167
#   To State SALState(step=91) with Probability 0.167
#   To State SALState(step=72) with Probability 0.167
# From State SALState(step=67):
#   To State SALState(step=68) with Probability 0.167
#   To State SALState(step=69) with Probability 0.167
#   To State SALState(step=70) with Probability 0.167
#   To State SALState(step=91) with Probability 0.167
#   To State SALState(step=72) with Probability 0.167
#   To State SALState(step=73) with Probability 0.167
# From State SALState(step=68):
#   To State SALState(step=69) with Probability 0.167
#   To State SALState(step=70) with Probability 0.167
#   To State SALState(step=91) with Probability 0.167
#   To State SALState(step=72) with Probability 0.167
#   To State SALState(step=73) with Probability 0.167
#   To State SALState(step=74) with Probability 0.167
# From State SALState(step=69):
#   To State SALState(step=70) with Probability 0.167
#   To State SALState(step=91) with Probability 0.167
#   To State SALState(step=72) with Probability 0.167
#   To State SALState(step=73) with Probability 0.167
#   To State SALState(step=74) with Probability 0.167
#   To State SALState(step=75) with Probability 0.167
# From State SALState(step=70):
#   To State SALState(step=91) with Probability 0.167
#   To State SALState(step=72) with Probability 0.167
#   To State SALState(step=73) with Probability 0.167
#   To State SALState(step=74) with Probability 0.167
#   To State SALState(step=75) with Probability 0.167
#   To State SALState(step=76) with Probability 0.167
# From State SALState(step=71):
#   To State SALState(step=72) with Probability 0.167
#   To State SALState(step=73) with Probability 0.167
#   To State SALState(step=74) with Probability 0.167
#   To State SALState(step=75) with Probability 0.167
#   To State SALState(step=76) with Probability 0.167
#   To State SALState(step=77) with Probability 0.167
# From State SALState(step=72):
#   To State SALState(step=73) with Probability 0.167
#   To State SALState(step=74) with Probability 0.167
#   To State SALState(step=75) with Probability 0.167
#   To State SALState(step=76) with Probability 0.167
#   To State SALState(step=77) with Probability 0.167
#   To State SALState(step=78) with Probability 0.167
# From State SALState(step=73):
#   To State SALState(step=74) with Probability 0.167
#   To State SALState(step=75) with Probability 0.167
#   To State SALState(step=76) with Probability 0.167
#   To State SALState(step=77) with Probability 0.167
#   To State SALState(step=78) with Probability 0.167
#   To State SALState(step=79) with Probability 0.167
# From State SALState(step=74):
#   To State SALState(step=75) with Probability 0.167
#   To State SALState(step=76) with Probability 0.167
#   To State SALState(step=77) with Probability 0.167
#   To State SALState(step=78) with Probability 0.167
#   To State SALState(step=79) with Probability 0.167
#   To State SALState(step=100) with Probability 0.167
# From State SALState(step=75):
#   To State SALState(step=76) with Probability 0.167
#   To State SALState(step=77) with Probability 0.167
#   To State SALState(step=78) with Probability 0.167
#   To State SALState(step=79) with Probability 0.167
#   To State SALState(step=100) with Probability 0.167
#   To State SALState(step=81) with Probability 0.167
# From State SALState(step=76):
#   To State SALState(step=77) with Probability 0.167
#   To State SALState(step=78) with Probability 0.167
#   To State SALState(step=79) with Probability 0.167
#   To State SALState(step=100) with Probability 0.167
#   To State SALState(step=81) with Probability 0.167
#   To State SALState(step=82) with Probability 0.167
# From State SALState(step=77):
#   To State SALState(step=78) with Probability 0.167
#   To State SALState(step=79) with Probability 0.167
#   To State SALState(step=100) with Probability 0.167
#   To State SALState(step=81) with Probability 0.167
#   To State SALState(step=82) with Probability 0.167
#   To State SALState(step=83) with Probability 0.167
# From State SALState(step=78):
#   To State SALState(step=79) with Probability 0.167
#   To State SALState(step=100) with Probability 0.167
#   To State SALState(step=81) with Probability 0.167
#   To State SALState(step=82) with Probability 0.167
#   To State SALState(step=83) with Probability 0.167
#   To State SALState(step=84) with Probability 0.167
# From State SALState(step=79):
#   To State SALState(step=100) with Probability 0.167
#   To State SALState(step=81) with Probability 0.167
#   To State SALState(step=82) with Probability 0.167
#   To State SALState(step=83) with Probability 0.167
#   To State SALState(step=84) with Probability 0.167
#   To State SALState(step=85) with Probability 0.167
# From State SALState(step=80):
#   To State SALState(step=81) with Probability 0.167
#   To State SALState(step=82) with Probability 0.167
#   To State SALState(step=83) with Probability 0.167
#   To State SALState(step=84) with Probability 0.167
#   To State SALState(step=85) with Probability 0.167
#   To State SALState(step=86) with Probability 0.167
# From State SALState(step=81):
#   To State SALState(step=82) with Probability 0.167
#   To State SALState(step=83) with Probability 0.167
#   To State SALState(step=84) with Probability 0.167
#   To State SALState(step=85) with Probability 0.167
#   To State SALState(step=86) with Probability 0.167
#   To State SALState(step=24) with Probability 0.167
# From State SALState(step=82):
#   To State SALState(step=83) with Probability 0.167
#   To State SALState(step=84) with Probability 0.167
#   To State SALState(step=85) with Probability 0.167
#   To State SALState(step=86) with Probability 0.167
#   To State SALState(step=24) with Probability 0.167
#   To State SALState(step=88) with Probability 0.167
# From State SALState(step=83):
#   To State SALState(step=84) with Probability 0.167
#   To State SALState(step=85) with Probability 0.167
#   To State SALState(step=86) with Probability 0.167
#   To State SALState(step=24) with Probability 0.167
#   To State SALState(step=88) with Probability 0.167
#   To State SALState(step=89) with Probability 0.167
# From State SALState(step=84):
#   To State SALState(step=85) with Probability 0.167
#   To State SALState(step=86) with Probability 0.167
#   To State SALState(step=24) with Probability 0.167
#   To State SALState(step=88) with Probability 0.167
#   To State SALState(step=89) with Probability 0.167
#   To State SALState(step=90) with Probability 0.167
# From State SALState(step=85):
#   To State SALState(step=86) with Probability 0.167
#   To State SALState(step=24) with Probability 0.167
#   To State SALState(step=88) with Probability 0.167
#   To State SALState(step=89) with Probability 0.167
#   To State SALState(step=90) with Probability 0.167
#   To State SALState(step=91) with Probability 0.167
# From State SALState(step=86):
#   To State SALState(step=24) with Probability 0.167
#   To State SALState(step=88) with Probability 0.167
#   To State SALState(step=89) with Probability 0.167
#   To State SALState(step=90) with Probability 0.167
#   To State SALState(step=91) with Probability 0.167
#   To State SALState(step=92) with Probability 0.167
# From State SALState(step=87):
#   To State SALState(step=88) with Probability 0.167
#   To State SALState(step=89) with Probability 0.167
#   To State SALState(step=90) with Probability 0.167
#   To State SALState(step=91) with Probability 0.167
#   To State SALState(step=92) with Probability 0.167
#   To State SALState(step=73) with Probability 0.167
# From State SALState(step=88):
#   To State SALState(step=89) with Probability 0.167
#   To State SALState(step=90) with Probability 0.167
#   To State SALState(step=91) with Probability 0.167
#   To State SALState(step=92) with Probability 0.167
#   To State SALState(step=73) with Probability 0.167
#   To State SALState(step=94) with Probability 0.167
# From State SALState(step=89):
#   To State SALState(step=90) with Probability 0.167
#   To State SALState(step=91) with Probability 0.167
#   To State SALState(step=92) with Probability 0.167
#   To State SALState(step=73) with Probability 0.167
#   To State SALState(step=94) with Probability 0.167
#   To State SALState(step=75) with Probability 0.167
# From State SALState(step=90):
#   To State SALState(step=91) with Probability 0.167
#   To State SALState(step=92) with Probability 0.167
#   To State SALState(step=73) with Probability 0.167
#   To State SALState(step=94) with Probability 0.167
#   To State SALState(step=75) with Probability 0.167
#   To State SALState(step=96) with Probability 0.167
# From State SALState(step=91):
#   To State SALState(step=92) with Probability 0.167
#   To State SALState(step=73) with Probability 0.167
#   To State SALState(step=94) with Probability 0.167
#   To State SALState(step=75) with Probability 0.167
#   To State SALState(step=96) with Probability 0.167
#   To State SALState(step=97) with Probability 0.167
# From State SALState(step=92):
#   To State SALState(step=73) with Probability 0.167
#   To State SALState(step=94) with Probability 0.167
#   To State SALState(step=75) with Probability 0.167
#   To State SALState(step=96) with Probability 0.167
#   To State SALState(step=97) with Probability 0.167
#   To State SALState(step=78) with Probability 0.167
# From State SALState(step=93):
#   To State SALState(step=94) with Probability 0.167
#   To State SALState(step=75) with Probability 0.167
#   To State SALState(step=96) with Probability 0.167
#   To State SALState(step=97) with Probability 0.167
#   To State SALState(step=78) with Probability 0.167
#   To State SALState(step=99) with Probability 0.167
# From State SALState(step=94):
#   To State SALState(step=75) with Probability 0.167
#   To State SALState(step=96) with Probability 0.167
#   To State SALState(step=97) with Probability 0.167
#   To State SALState(step=78) with Probability 0.167
#   To State SALState(step=99) with Probability 0.167
#   To State SALState(step=100) with Probability 0.167
# From State SALState(step=95):
#   To State SALState(step=96) with Probability 0.167
#   To State SALState(step=97) with Probability 0.167
#   To State SALState(step=78) with Probability 0.167
#   To State SALState(step=99) with Probability 0.167
#   To State SALState(step=100) with Probability 0.333
# From State SALState(step=96):
#   To State SALState(step=97) with Probability 0.167
#   To State SALState(step=78) with Probability 0.167
#   To State SALState(step=99) with Probability 0.167
#   To State SALState(step=100) with Probability 0.500
# From State SALState(step=97):
#   To State SALState(step=78) with Probability 0.167
#   To State SALState(step=99) with Probability 0.167
#   To State SALState(step=100) with Probability 0.667
# From State SALState(step=98):
#   To State SALState(step=99) with Probability 0.167
#   To State SALState(step=100) with Probability 0.833
# From State SALState(step=99):
#   To State SALState(step=100) with Probability 1.000
# SALState(step=100) is a Terminal State

# %%
def trace_distribution(trace:Generator[SALState, None, None],nSample:int) -> np.ndarray:
    result=[]
    for _ in range(nSample):
        i=next(trace)
        counter=0
        while True:
            try:
                next(i)
                counter=counter+1
            except StopIteration:
                break
        result.append(counter)
    return np.array(result)

# %% [markdown]
# <a id='Q1'></a>

# %%
trace=newGame.traces(start_state_distribution=Constant(SALState(0)))
samples=trace_distribution(trace=trace,nSample=10000)
plt.hist(samples,density=True)
plt.show()

# %%
class SALMRPFinite(FiniteMarkovRewardProcess[SALState]):

    def __init__(
        self,
        snakePos: np.ndarray,
        ladderPos: np.ndarray
    ):
        self.snakePos: np.ndarray = snakePos
        self.ladderPos: np.ndarray = ladderPos
        super().__init__(self.get_transition_reward_map())

    def get_transition_reward_map(self) -> RewardTransition[SALState]:
        d: Dict[SALState, Categorical[Tuple[SALState, float]]] = {}
        for currentStep in range(100):
            sr_probs_map: Dict[Tuple[SALState, float], float] ={}
            for dice in range(1,7):
                #probMutiplier is used to capture the corner cases near destination
                finalStep,probMultiplier = self.get_final_state(currentStep+dice)
                reward=1
                sr_probs_map[(SALState(int(finalStep)), reward)] = probMultiplier*1/6
                d[SALState(currentStep)] = Categorical(sr_probs_map)
        d[SALState(100)]=None
        return d
    
    def get_final_state(self,nxtStep: int) -> Tuple[int,int]:
        """Use Recursion to get final location wrt nxtStep
        """
        # arrive or go beyond destination
        if nxtStep>99:
            probMultiplier=nxtStep-99
            step=100
        else:
            probMultiplier=1
            step=nxtStep
        # snake and ladder cases
        for snake in self.snakePos:
            if snake[0]==nxtStep:
                step,probMultiplier=self.get_final_state(snake[1])
                break
                
        for ladder in self.ladderPos:
            if ladder[0]==nxtStep:
                step,probMultiplier=self.get_final_state(ladder[1])
                break
        return step,probMultiplier

# %%
# Expected number of time steps:{SALState(step=0): 35.692}
reward_game=SALMRPFinite(        
    snakePos=snake.getSAL(),
    ladderPos=ladder.getSAL() 
)
reward_game.display_value_function(1)
# Out:
# {SALState(step=3): 35.664,
#  SALState(step=5): 35.758,
#  SALState(step=4): 35.932,
#  SALState(step=1): 36.335,
#  SALState(step=0): 35.692,
#  SALState(step=2): 36.154,
#  SALState(step=21): 31.807,
#  SALState(step=22): 29.921,
#  SALState(step=23): 30.418,
#  SALState(step=24): 30.772,
#  SALState(step=25): 31.052,
#  SALState(step=31): 32.728,
#  SALState(step=32): 32.546,
#  SALState(step=33): 32.321,
#  SALState(step=34): 32.062,
#  SALState(step=35): 31.856,
#  SALState(step=36): 31.885,
#  SALState(step=26): 31.265,
#  SALState(step=27): 31.416,
#  SALState(step=28): 33.659,
#  SALState(step=29): 33.402,
#  SALState(step=30): 32.897,
#  SALState(step=37): 31.718,
#  SALState(step=38): 31.454,
#  SALState(step=39): 30.967,
#  SALState(step=40): 30.51,
#  SALState(step=41): 30.618,
#  SALState(step=10): 35.182,
#  SALState(step=11): 34.712,
#  SALState(step=12): 34.285,
#  SALState(step=13): 33.906,
#  SALState(step=14): 33.574,
#  SALState(step=15): 33.07,
#  SALState(step=42): 30.046,
#  SALState(step=43): 30.713,
#  SALState(step=44): 29.868,
#  SALState(step=45): 28.051,
#  SALState(step=46): 27.762,
#  SALState(step=47): 26.843,
#  SALState(step=52): 26.032,
#  SALState(step=48): 26.62,
#  SALState(step=49): 24.962,
#  SALState(step=50): 24.796,
#  SALState(step=51): 26.319,
#  SALState(step=7): 35.313,
#  SALState(step=6): 35.548,
#  SALState(step=8): 35.065,
#  SALState(step=9): 35.122,
#  SALState(step=53): 25.749,
#  SALState(step=56): 25.748,
#  SALState(step=55): 24.768,
#  SALState(step=54): 25.279,
#  SALState(step=57): 24.766,
#  SALState(step=64): 17.92,
#  SALState(step=65): 16.998,
#  SALState(step=67): 17.15,
#  SALState(step=66): 17.083,
#  SALState(step=68): 16.85,
#  SALState(step=60): 22.458,
#  SALState(step=58): 24.6,
#  SALState(step=59): 23.333,
#  SALState(step=61): 21.7,
#  SALState(step=62): 19.236,
#  SALState(step=63): 18.878,
#  SALState(step=16): 32.132,
#  SALState(step=17): 31.887,
#  SALState(step=18): 31.728,
#  SALState(step=19): 31.631,
#  SALState(step=20): 31.579,
#  SALState(step=69): 16.727,
#  SALState(step=70): 16.714,
#  SALState(step=71): 17.646,
#  SALState(step=72): 17.594,
#  SALState(step=73): 17.555,
#  SALState(step=74): 15.047,
#  SALState(step=75): 15.99,
#  SALState(step=76): 16.636,
#  SALState(step=77): 17.057,
#  SALState(step=78): 17.278,
#  SALState(step=79): 17.321,
#  SALState(step=80): 20.126,
#  SALState(step=81): 21.646,
#  SALState(step=82): 20.512,
#  SALState(step=83): 19.585,
#  SALState(step=84): 18.602,
#  SALState(step=85): 17.582,
#  SALState(step=86): 16.826,
#  SALState(step=87): 14.623,
#  SALState(step=88): 13.702,
#  SALState(step=89): 14.029,
#  SALState(step=90): 12.699,
#  SALState(step=91): 11.463,
#  SALState(step=92): 12.294,
#  SALState(step=93): 9.534,
#  SALState(step=94): 8.172,
#  SALState(step=97): 4.046,
#  SALState(step=95): 5.507,
#  SALState(step=96): 4.721,
#  SALState(step=98): 1.167,
#  SALState(step=99): 1.0}

# %% [markdown]
# <h1><center>Snakes and Ladders(p1,p2,p4)</center></h1>

# %%
@dataclass(frozen=True)
class LotusState:
    '''Frog Puzzle State Object
    '''
    step: int

class FrogPuzzleFinite(FiniteMarkovRewardProcess[LotusState]):
    '''Frog Puzzle Game with nState+2 states in total: nState Lotus and 0,nState+1 represent two banks of river.
    As we set reward=1, value function of state 0 is the expected number of hops.
    '''
    def __init__(
        self,
        nState: int
    ):
        self.nState: int = nState
        super().__init__(self.get_transition_reward_map())

    def get_transition_reward_map(self) -> RewardTransition[LotusState]:
        d: Dict[LotusState, Categorical[Tuple[LotusState, float]]] = {}
        for currentStep in range(self.nState+1):
            sr_probs_map: Dict[Tuple[LotusState, float], float] ={}
            for nxtStep in range(currentStep+1,self.nState+2):
                reward=1
                sr_probs_map[(LotusState(nxtStep), reward)] = 1/(self.nState-currentStep+1)
                d[LotusState(currentStep)] = Categorical(sr_probs_map)
        d[LotusState(self.nState+1)]=None
        return d

# %%
new_puzzle=FrogPuzzleFinite(10)
print("Transition Map")
print("--------------")
print(FiniteMarkovProcess(new_puzzle.transition_map))
new_puzzle.display_value_function(1)
# Out:
# Transition Map
# --------------
# From State LotusState(step=0):
#   To State LotusState(step=1) with Probability 0.091
#   To State LotusState(step=2) with Probability 0.091
#   To State LotusState(step=3) with Probability 0.091
#   To State LotusState(step=4) with Probability 0.091
#   To State LotusState(step=5) with Probability 0.091
#   To State LotusState(step=6) with Probability 0.091
#   To State LotusState(step=7) with Probability 0.091
#   To State LotusState(step=8) with Probability 0.091
#   To State LotusState(step=9) with Probability 0.091
#   To State LotusState(step=10) with Probability 0.091
#   To State LotusState(step=11) with Probability 0.091
# From State LotusState(step=1):
#   To State LotusState(step=2) with Probability 0.100
#   To State LotusState(step=3) with Probability 0.100
#   To State LotusState(step=4) with Probability 0.100
#   To State LotusState(step=5) with Probability 0.100
#   To State LotusState(step=6) with Probability 0.100
#   To State LotusState(step=7) with Probability 0.100
#   To State LotusState(step=8) with Probability 0.100
#   To State LotusState(step=9) with Probability 0.100
#   To State LotusState(step=10) with Probability 0.100
#   To State LotusState(step=11) with Probability 0.100
# From State LotusState(step=2):
#   To State LotusState(step=3) with Probability 0.111
#   To State LotusState(step=4) with Probability 0.111
#   To State LotusState(step=5) with Probability 0.111
#   To State LotusState(step=6) with Probability 0.111
#   To State LotusState(step=7) with Probability 0.111
#   To State LotusState(step=8) with Probability 0.111
#   To State LotusState(step=9) with Probability 0.111
#   To State LotusState(step=10) with Probability 0.111
#   To State LotusState(step=11) with Probability 0.111
# From State LotusState(step=3):
#   To State LotusState(step=4) with Probability 0.125
#   To State LotusState(step=5) with Probability 0.125
#   To State LotusState(step=6) with Probability 0.125
#   To State LotusState(step=7) with Probability 0.125
#   To State LotusState(step=8) with Probability 0.125
#   To State LotusState(step=9) with Probability 0.125
#   To State LotusState(step=10) with Probability 0.125
#   To State LotusState(step=11) with Probability 0.125
# From State LotusState(step=4):
#   To State LotusState(step=5) with Probability 0.143
#   To State LotusState(step=6) with Probability 0.143
#   To State LotusState(step=7) with Probability 0.143
#   To State LotusState(step=8) with Probability 0.143
#   To State LotusState(step=9) with Probability 0.143
#   To State LotusState(step=10) with Probability 0.143
#   To State LotusState(step=11) with Probability 0.143
# From State LotusState(step=5):
#   To State LotusState(step=6) with Probability 0.167
#   To State LotusState(step=7) with Probability 0.167
#   To State LotusState(step=8) with Probability 0.167
#   To State LotusState(step=9) with Probability 0.167
#   To State LotusState(step=10) with Probability 0.167
#   To State LotusState(step=11) with Probability 0.167
# From State LotusState(step=6):
#   To State LotusState(step=7) with Probability 0.200
#   To State LotusState(step=8) with Probability 0.200
#   To State LotusState(step=9) with Probability 0.200
#   To State LotusState(step=10) with Probability 0.200
#   To State LotusState(step=11) with Probability 0.200
# From State LotusState(step=7):
#   To State LotusState(step=8) with Probability 0.250
#   To State LotusState(step=9) with Probability 0.250
#   To State LotusState(step=10) with Probability 0.250
#   To State LotusState(step=11) with Probability 0.250
# From State LotusState(step=8):
#   To State LotusState(step=9) with Probability 0.333
#   To State LotusState(step=10) with Probability 0.333
#   To State LotusState(step=11) with Probability 0.333
# From State LotusState(step=9):
#   To State LotusState(step=10) with Probability 0.500
#   To State LotusState(step=11) with Probability 0.500
# From State LotusState(step=10):
#   To State LotusState(step=11) with Probability 1.000
# LotusState(step=11) is a Terminal State
#
# {LotusState(step=3): 2.718,
#  LotusState(step=2): 2.829,
#  LotusState(step=1): 2.929,
#  LotusState(step=10): 1.0,
#  LotusState(step=0): 3.02,
#  LotusState(step=6): 2.283,
#  LotusState(step=5): 2.45,
#  LotusState(step=9): 1.5,
#  LotusState(step=8): 1.833,
#  LotusState(step=4): 2.593,
#  LotusState(step=7): 2.083}

# %% [markdown]
# <h1><center>Stock Price (p5)</center></h1>

# %% [markdown]
# <a id='Q3'></a>

# %%
@dataclass(frozen=True)
class StateMP1:
    price: int

@dataclass(frozen=False)        
class StockPriceMP1(MarkovRewardProcess[StateMP1]):
    ''' A class that implements the interface of the @abstractclass MarkovRewardProcess and allow flexibility in
        specifying your own function f. This is an infinite-states, non-terminating MRP. Compute it’s
        Value Function for any discount factor 0 ≤ γ < 1.
    '''
    level_param: int  # level to which price mean-reverts
    alpha1: float  # strength of mean-reversion (non-negative value)
    f: Callable[[int], float]# reward is function f of stock price
    def up_prob(self, state: StateMP1) -> float:
        return get_logistic_func(self.alpha1)(self.level_param - state.price)

    def transition_reward(self, state: StateMP1) -> Optional[Distribution[Tuple[StateMP1, float]]]:
        '''Given a state, returns a distribution of the next state
        and reward from transitioning between the states.
        '''
        up_p = self.up_prob(state)
        reward_up=self.f(StateMP1(state.price + 1))
        reward_down=self.f(StateMP1(state.price - 1))
        return Categorical({
            (StateMP1(state.price + 1),reward_up): up_p,
            (StateMP1(state.price - 1),reward_down): 1 - up_p
        })
